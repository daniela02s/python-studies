# %% [markdown]
# #### **Exercícios**

# %% [markdown]
# O dataset Medical Cost Personal Datasets é uma base de dados clássica para o aprendizado de análise de dados e machine learning, pois contém informações socioeconômicas e demográficas reais de pacientes. O objetivo principal é entender como diferentes fatores — como hábitos de vida e características físicas — impactam diretamente no valor final das faturas de seguro saúde.
#
# Os dados são estruturados de forma tabular, contendo sete colunas que misturam variáveis numéricas (idade e IMC) com variáveis categóricas (gênero, região e se o paciente é fumante). Essa variedade permite exercitar técnicas fundamentais do Pandas, como a criação de filtros específicos, o agrupamento de categorias para comparar médias e a detecção de valores discrepantes (outliers).
#
# A análise deste conjunto costuma revelar correlações interessantes, como o impacto drástico do tabagismo nos custos hospitalares e a relação entre o número de dependentes e as taxas cobradas. Por ser um dataset limpo e bem organizado, ele é o ponto de partida ideal para praticar funções essenciais como describe(), groupby() e value_counts().
#
# <div align="center">
#     <img src="image-data-medical.png" width="800">
# </div>

# %% [markdown]
# **1)** Importe os dados e verifique as primeiras linhas do dataset. Verifique também as últimas linhas do dataset.

# %%
# Importando bibliotecas necessárias

import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Importando bibliotecas necessárias
# ----> 3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'
